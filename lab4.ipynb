# %% [markdown]
# ##Challenge 1:

# %%
# Upload local script to Colab here.
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc81b4e2-f60f-4f9a-a088-d89e7ac21e91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc81b4e2-f60f-4f9a-a088-d89e7ac21e91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airports.csv to airports.csv
# Saving routes.csv to routes.csv

# %%
import csv
f = open("airports.csv")
for row in csv.reader(f):
  if "Poland" in row[3]:
    print(row[1])
# Out:
# Babice Airport
# Gdańsk Lech Wałęsa Airport
# Kraków John Paul II International Airport
# Muchowiec Airport
# Katowice International Airport
# Mielec Airport
# Poznań-Ławica Airport
# Rzeszów-Jasionka Airport
# Szczecin-Goleniów "Solidarność" Airport
# Redzikowo Air Base
# Swidwin Military Air Base
# Warsaw Chopin Airport
# Copernicus Wrocław Airport
# Zielona Góra-Babimost Airport
# Bydgoszcz Ignacy Jan Paderewski Airport
# Łódź Władysław Reymont Airport
# Szczecin-Dąbie Airport
# Bielsko Biala Airport
# Lotnisko Korne
# Oksywie Military Air Base
# Malbork Military Air Base
# Lask Military Air Base
# Miroslawiec Military Air Base
# Krzesiny Military Air Base
# Radom Airport
# Modlin Airport
# Inowroclaw Military Air Base
# Pruszcz Gdanski Air Base
# Góraszka Airport
# Lublin Airport
# Olsztyn-Mazury Airport
# Jelenia Góra Glider Airport
# Biała Podlaska Airfield
# Cewice Air Base
# Deblin Military Air Base
# Leczyca Military Air Base
# Minsk Mazowiecki Military Air Base
# ...

# %%
import csv
with open('airports.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row["1"], row["-6.081689834590001"])
# Out:
# Streaming output truncated to the last 5000 lines.
# 2842 10.462474
# 2843 10.794432
# 2844 11.78077507019043
# 2845 9.906952857971191
# 2846 8.239167213439941
# 2847 11.80720043182373
# 2848 10.5582084656
# 2849 8.582078
# 2850 10.912603378295898
# 2851 10.601194
# 2852 9.75452995300293
# 2853 5.6199898719788
# 2854 10.480500221252441
# 2855 7.8013200759887695
# 2856 8.288530349731445
# 2857 7.566669940948486
# 2858 7.840829849243164
# 2859 7.803514003753662
# 2860 4.554999828338623
# 2861 7.56538
# 2862 10.2787
# 2863 7.883319854736328
# 2864 8.9451465606689
# 2865 8.974550247192383
# 2866 9.088994026184082
# 2867 7.24938
# 2868 10.14973258972168
# 2870 9.34047794342041
# 2871 9.22202777863
# 2872 5.96592
# 2873 3.37276
# 2874 17.1367
# 2875 13.0746002197
# 2876 15.336700439453125
# 2877 15.547
# 2878 14.590999603271484
# 2879 18.099899291992
# 2881 16.265301
# 2882 12.004199981689453
# 2883 18.337299346923828
# 2884 17.701900482177734
# 2885 18.49489974975586
# ...
